# %%
import numpy as np
import math

# %%
x = np.linspace(-math.pi, math.pi, 2000)
y = np.sin(x)

# %%
a = np.random.randn()
b = np.random.randn()
c = np.random.randn()
d = np.random.randn()

# %%
learning_rate = 1e-6

# %%
for t in range(2000):
  y_pred = a + b * x + c * x ** 2 + d * x ** 3

  loss = np.square(y_pred - y).sum()
  if t%100 == 99:
    print(t, loss)

  grad_y_pred = 2.0 * (y_pred - y)
  grad_a = grad_y_pred.sum()
  grad_b = (grad_y_pred * x).sum()
  grad_c = (grad_y_pred * x ** 2).sum()
  grad_d = (grad_y_pred * x ** 3).sum()

  a -= learning_rate * grad_a
  b -= learning_rate * grad_b
  c -= learning_rate * grad_c
  d -= learning_rate * grad_d

print(f'Result: y = {a} + {b}x + {c}x^2 + {d}x^3')
# Out:
# 99 8.817741043755168
# 199 8.817565999209197
# 299 8.817444418307058
# 399 8.817359895401497
# 499 8.817301083761846
# 599 8.817260127599232
# 699 8.817231582638772
# 799 8.817211672198727
# 899 8.8171977739376
# 999 8.817188065367688
# 1099 8.817181278766768
# 1199 8.817176531552768
# 1299 8.817173208768658
# 1399 8.817170881589389
# 1499 8.817169250755288
# 1599 8.817168107271343
# 1699 8.817167305077874
# 1799 8.817166742029535
# 1899 8.817166346645756
# 1999 8.817166068874013
# Result: y = -2.5983316705503936e-05 + 0.8567335501517531x + 4.482554495952399e-06x^2 + -0.09332935168594722x^3
